# %% [markdown]
# ##CUNY - Data 612
#
# #Project 5
# #Implementing a Recommender System on Spark
#
# ##Peter Kowalchuk and Violeta Stoyanova

# %% [markdown]
# #Introduction
#
# The purpose of this project is to build a recommender system using the same dataset as in previous project https://rpubs.com/pkowalchuk/588534 and compare the performance with the previous iteration. The dataset is derived from Amazon and consists of users' ratings of instant videos. In the previous project, Project 4, both item (IBCF) and user (UBCF) based collaborative filtering recommenders were designed on a reduced set (80k entries) of data from the Amazon dataset. It was not possible to train a model with a larger dataset on an on-premise setting or without using a distributed machine-learning framework.
# In Project 5, the whole dataset will be used (over 500k entries) and will be adapted to work with Apache Spark via Databricks Community Edition. An Alternating Least Squares (ALS) model was chosen instead of ICBF and UBCF. ALS is an algorithm very well suited for distributed computing since it is an iterative process.
# “ALS recommender is a matrix factorization algorithm that uses Alternating Least Squares with Weighted-Lamda-Regularization (ALS-WR). It factors the user to item matrix A into the user-to-feature matrix U and the item-to-feature matrix M: It runs the ALS algorithm in a parallel fashion.  The ALS algorithm should uncover the latent factors that explain the observed user to item ratings and tries to find optimal factor weights to minimize the least squares between predicted and actual ratings.” –
# https://www.elenacuoco.com/2016/12/22/alternating-least-squares-als-spark-ml/?cn-reloaded=1

# %% [markdown]
# #Load Data
#
# Datasets are available on Julian McAuley’s site: http://jmcauley.ucsd.edu/data/amazon/links.html
# The csv file for Instant Video was uploaded onto the databricks file system using the UI. The file is then loaded onto a Databricks dataframe.

# %%
# File location and type
file_location = "/FileStore/tables/ratings_Amazon_Instant_Video.csv"
file_type = "csv"

# CSV options
infer_schema = "false"
first_row_is_header = "false"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
data = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th><th>_c3</th></tr></thead><tbody><tr><td>A1EE2E3N7PW666</td><td>B000GFDAUG</td><td>5.0</td><td>1202256000</td></tr><tr><td>AGZ8SM1BGK3CK</td><td>B000GFDAUG</td><td>5.0</td><td>1198195200</td></tr><tr><td>A2VHZ21245KBT7</td><td>B000GIOPK2</td><td>4.0</td><td>1215388800</td></tr><tr><td>ACX8YW2D5EGP6</td><td>B000GIOPK2</td><td>4.0</td><td>1185840000</td></tr><tr><td>A9RNMO9MUSMTJ</td><td>B000GIOPK2</td><td>2.0</td><td>1281052800</td></tr><tr><td>A3STFVPM8NHJ7B</td><td>B000GIOPK2</td><td>5.0</td><td>1203897600</td></tr><tr><td>A2582KMXLK2P06</td><td>B000GIOPK2</td><td>5.0</td><td>1205884800</td></tr><tr><td>A1TZCLCW9QGGBH</td><td>B000GIOPK2</td><td>4.0</td><td>1209427200</td></tr><tr><td>A2E2I6B878CRMA</td><td>B000GIOPK2</td><td>5.0</td><td>1378684800</td></tr><tr><td>AD5MZA8SOVMPJ</td><td>B000GIOPK2</td><td>5.0</td><td>1218240000</td></tr><tr><td>A3IE1M3QVUKIJN</td><td>B000GIOPK2</td><td>5.0</td><td>1251763200</td></tr><tr><td>AZ1MUCW76BDL1</td><td>B000GIOPK2</td><td>5.0</td><td>1361145600</td></tr><tr><td>A2XNOB1T796Y6B</td><td>B000GIOPK2</td><td>5.0</td><td>1233532800</td></tr><tr><td>A12DO7F3TT123V</td><td>B000GIOPK2</td><
count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Total number of user/item ratings in dataset
# <span class="ansired">Out[</span><span class="ansired">3</span><span class="ansired">]: </span>(None, &apos;583933&apos;)</div>

# %% [markdown]
# Build dataframe with average ratings for movies and movie counts

# %%
from pyspark.sql import functions as F

item_ids_with_avg_ratings_df = data.groupBy('itemId').agg(F.count(data.rating).alias("Count"), F.avg(data.rating).alias("average"))
print ('item_ids_with_avg_ratings_df:')
item_ids_with_avg_ratings_df.show(5, truncate=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">item_ids_with_avg_ratings_df:
# +----------+-----+-----------------+
# itemId    |Count|average          |
# +----------+-----+-----------------+
# B000OC3FZQ|78   |4.551282051282051|
# B000P41FAA|2    |3.5              |
# B000RKQEQW|2    |5.0              |
# B000TS73MG|2    |5.0              |
# B000U5IH7I|12   |4.583333333333333|
# +----------+-----+-----------------+
# only showing top 5 rows
#
# </div>

# %%
print("Total number of items in dataset"),item_ids_with_avg_ratings_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Total number of items in dataset
# <span class="ansired">Out[</span><span class="ansired">5</span><span class="ansired">]: </span>(None, 23965)</div>

# %% [markdown]
# #Select relevant data
#
# To build this model we are going to select items with a 1000 or more reviews

# %%
from pyspark.sql.functions import col
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
items_with_many_ratings_or_more = item_ids_with_avg_ratings_df.filter(item_ids_with_avg_ratings_df.Count>1000).sort(col("average").desc())
print ('Items with highest ratings:')
items_with_many_ratings_or_more.show(20, truncate=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Items with highest ratings:
# +----------+-----+------------------+
# itemId    |Count|average           |
# +----------+-----+------------------+
# B009IG59DK|1309 |4.881588999236058 |
# B00CE10BD4|1067 |4.878163074039363 |
# B00DTOYIIE|6927 |4.857947163274145 |
# B003NRWVMC|1132 |4.845406360424028 |
# B0083IJGBU|1401 |4.844396859386153 |
# B009IF7092|1191 |4.812762384550798 |
# B00APE00H4|4501 |4.808487002888247 |
# B004MWZLYC|3286 |4.804930006086427 |
# B0040HNZTW|2136 |4.7911985018726595|
# B00FMO8DXU|1694 |4.78689492325856  |
# B0099JKR6U|3884 |4.78681771369722  |
# B00D1N6OQ2|1005 |4.782089552238806 |
# B006Z48TZS|3680 |4.775271739130435 |
# B004KPX56C|1303 |4.768994627782042 |
# B008QTTGGG|3230 |4.768730650154799 |
# B008BQ8VOC|2723 |4.764965112008814 |
# B009FZFONO|6838 |4.763819830359754 |
# B005544TRQ|4540 |4.754405286343612 |
# B00F406S2U|1172 |4.739761092150171 |
# B00BLCHL4Y|3596 |4.735261401557286 |
# +----------+-----+------------------+
# only showing top 20 rows
#
# </div>

# %%
print("Number of items with many ratings:"),items_with_many_ratings_or_more.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Number of items with many ratings:
# <span class="ansired">Out[</span><span class="ansired">8</span><span class="ansired">]: </span>(None, 69)</div>

# %%
df=data.join(items_with_many_ratings_or_more,data.itemId==items_with_many_ratings_or_more.itemId).drop(items_with_many_ratings_or_more.itemId)
print("Number of user/item ratings with items with more than 1000 ratings"),df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Number of user/item ratings with items with more than 1000 ratings
# <span class="ansired">Out[</span><span class="ansired">9</span><span class="ansired">]: </span>(None, 192377)</div>

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>rating</th><th>itemId</th><th>Count</th><th>average</th></tr></thead><tbody><tr><td>A3OSZISQRMTWZX</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>AUMYZ3TS44MNP</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A3RA3ZTC0HDP9U</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A18NIX1QH8L1Z9</td><td>4.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A1HQ4RXXJNS5TC</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A36GS5K3YYXFMX</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A34IPQQL7NIJQL</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A20ZO8UFW5EFS6</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A38IOP4TW32Y2Q</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A133G8UNAV44BP</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>AEKZL04PZT00E</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A2ZTOTUEBOOFQO</td><td>4.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A1ZN17SY8B3LCZ</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A3P6L56GUQ85Q2</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A1AUP6RUJD01IW</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A1S7DJPSFDSEIW</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>AFTCML5ZKDJ2F</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A1EUIHORKSTT3T</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>AP3JFZYTXTD68</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>AT0CF2RA9EZHG</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A1M0OOSTWL760H</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A11J7EOZFK4VX0</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A3MICL5RG8QZX7</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A2CUZL460CVQP5</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A1GP6FF2KAJ4OQ</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A4YOGHJ318UGY</td><td>4.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>AYJKFTHNF6BYD</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A2MYD85NGIUWE6</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>APT5R9GEC52L8</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A5TDOCTCGY19V</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A3NT2KWVZ8WEBJ</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A2QYY2GU66WDXU</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>AGOYTDOB23CNY</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A1C7AQVHUDWFY4</td><td>4.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>ASV9ERSOWJN5V</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A2G10P9DQS555B</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>ALE8NCB09O7PG</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td></tr><tr><td>A193F6OTQGTWFJ</td>< ...

# %% [markdown]
# #Prepare dataframe for pySpark
#
# In order to build a model using pySpark ALS we have to remove the strings from the user and item variables since pySpark ALS does not take strings. The next step is to create corresponding numeric indecies for user and items.
# From Apache Spark Documentation
# Note: The DataFrame-based API for ALS currently only supports integers for user and item ids. Other numeric types are supported for the user and item id columns, but the ids must be within the integer value range.

# %%
from pyspark.ml.feature import StringIndexer
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
stringIndexer = StringIndexer(inputCol="userId", outputCol="userIndex")
model = stringIndexer.fit(df)
dataIndexed = model.transform(df)

stringIndexer = StringIndexer(inputCol="itemId", outputCol="itemIndex")
model = stringIndexer.fit(dataIndexed)
dataIndexed = model.transform(dataIndexed)

display(dataIndexed)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>rating</th><th>itemId</th><th>Count</th><th>average</th><th>userIndex</th><th>itemIndex</th></tr></thead><tbody><tr><td>A3OSZISQRMTWZX</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>3930.0</td><td>60.0</td></tr><tr><td>AUMYZ3TS44MNP</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>31909.0</td><td>60.0</td></tr><tr><td>A3RA3ZTC0HDP9U</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>15727.0</td><td>60.0</td></tr><tr><td>A18NIX1QH8L1Z9</td><td>4.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>85495.0</td><td>60.0</td></tr><tr><td>A1HQ4RXXJNS5TC</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>114301.0</td><td>60.0</td></tr><tr><td>A36GS5K3YYXFMX</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>148614.0</td><td>60.0</td></tr><tr><td>A34IPQQL7NIJQL</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>65610.0</td><td>60.0</td></tr><tr><td>A20ZO8UFW5EFS6</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>6588.0</td><td>60.0</td></tr><tr><td>A38IOP4TW32Y2Q</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>48178.0</td><td>60.0</td></tr><tr><td>A133G8UNAV44BP</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>6488.0</td><td>60.0</td></tr><tr><td>AEKZL04PZT00E</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>98198.0</td><td>60.0</td></tr><tr><td>A2ZTOTUEBOOFQO</td><td>4.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>68385.0</td><td>60.0</td></tr><tr><td>A1ZN17SY8B3LCZ</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>15333.0</td><td>60.0</td></tr><tr><td>A3P6L56GUQ85Q2</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>61458.0</td><td>60.0</td></tr><tr><td>A1AUP6RUJD01IW</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>41994.0</td><td>60.0</td></tr><tr><td>A1S7DJPSFDSEIW</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>45869.0</td><td>60.0</td></tr><tr><td>AFTCML5ZKDJ2F</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>97242.0</td><td>60.0</td></tr><tr><td>A1EUIHORKSTT3T</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>17691.0</td><td>60.0</td></tr><tr><td>AP3JFZYTXTD68</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>133950.0</td><td>60.0</td></tr><tr><td>AT0CF2RA9EZHG</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>3806.0</td><td>60.0</td></tr><tr><td>A1M0OOSTWL760H</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>13405.0</td><td>60.0</td></tr><tr><td>A11J7EOZFK4VX0</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>143551.0</td><td>60.0</td></tr><tr><td>A3MICL5RG8QZX7</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>73525.0</td><td>60.0</td></tr><tr><td>A2CUZL460CVQP5</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>147672.0</td><td>60.0</td></tr><tr><td>A1GP6FF2KAJ4OQ</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>88070.0</td><td>60.0</td></tr><tr><td>A4YOGHJ318UGY</td><td>4.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>48197.0</td><td>60.0</td></tr><tr><td>AYJKFTHNF6BYD</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>9639.0</td><td>60.0</td></tr><tr><td>A2MYD85NGIUWE6</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028</td><td>106558.0</td><td>60.0</td></tr><tr><td>APT5R9GEC52L8</td><td>5.0</td><td>B003NRWVMC</td><td>1132</td><td>4.845406360424028< ...

# %%
dataIndexed.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- userId: string (nullable = true)
# -- rating: string (nullable = true)
# -- itemId: string (nullable = true)
# -- Count: long (nullable = false)
# -- average: double (nullable = true)
# -- userIndex: double (nullable = false)
# -- itemIndex: double (nullable = false)
#
# </div>

# %% [markdown]
# Now we have userIndex, itemIndex corresponding with userId and ItemId and we are going to select only the columns required for modeling and cast rating as a float

# %%
df=dataIndexed.select(dataIndexed.userId,dataIndexed.itemId,dataIndexed.rating.cast("float"),dataIndexed.userIndex,dataIndexed.itemIndex)
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- userId: string (nullable = true)
# -- itemId: string (nullable = true)
# -- rating: float (nullable = true)
# -- userIndex: double (nullable = false)
# -- itemIndex: double (nullable = false)
#
# </div>

# %% [markdown]
# Split data .8 train and .2 test

# %%
(training,test)=df.randomSplit([0.8,0.2])

print('Training: {0}, test: {1}\n'.format(
  training.count(), test.count())
)
training.show(3)
test.show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Training: 154056, test: 38321
#
# +--------------------+----------+------+---------+---------+
#               userId|    itemId|rating|userIndex|itemIndex|
# +--------------------+----------+------+---------+---------+
# A004476834K8BM0W3...|B000MVN8GK|   5.0|  94042.0|     51.0|
# A03373291U5ZIN1CQ...|B000MVN8GK|   4.0| 107488.0|     51.0|
# A04679053BE8ZYGJ7...|B000VZUWZW|   4.0|  42554.0|     56.0|
# +--------------------+----------+------+---------+---------+
# only showing top 3 rows
#
# +--------------+----------+------+---------+---------+
#         userId|    itemId|rating|userIndex|itemIndex|
# +--------------+----------+------+---------+---------+
# A100SBTKAMHC8R|B001F6ZIXC|   5.0| 120378.0|     30.0|
# A103JQ41DH2YU9|B000MVN8HE|   1.0| 156114.0|     32.0|
# A106WN5A9FJJGQ|B000MVN8HE|   4.0| 123823.0|     32.0|
# +--------------+----------+------+---------+---------+
# only showing top 3 rows
#
# </div>

# %% [markdown]
# #Model
#
# Train ALS models with different K

# %%
from pyspark.ml.recommendation import ALS
from pyspark.ml.tuning import TrainValidationSplit,ParamGridBuilder
from pyspark.ml.evaluation import RegressionEvaluator
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# "ALS is an iterative optimization process where we for every iteration try to arrive closer and closer to a factorized representation of our original data."
# Just like other recommender systems ALS has it's own hyper-parameters that need to be tuned and for that purpose we are using the build-in function ParamGridBuilder to come up with the best combination of:
#
# •	rank: the number of latent factors in the model (defaults to 10)
# •	maxIter: the maximum number of iterations to run (defaults to 10)
# •	regParam: the regularization parameter in ALS (defaults to 1.0)

# %%
als = ALS()

als.setUserCol('userIndex')\
   .setItemCol('itemIndex')

param_grid=ParamGridBuilder()\
            .addGrid(als.rank,[8,12,20])\
            .addGrid(als.maxIter,[10,20])\
            .addGrid(als.regParam,[.05, .1])\
            .build()

evaluator=RegressionEvaluator(metricName="rmse",labelCol="rating",predictionCol="prediction")

tvs=TrainValidationSplit(estimator=als,estimatorParamMaps=param_grid,evaluator=evaluator)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Import mlflow
import mlflow
import mlflow.sklearn
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Mon Apr 20 12:33:02 2020 py4j imported
# </div>

# %%
model=tvs.fit(training)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# java.io.IOException: Connection failed
# 	at com.databricks.rpc.Jetty9Client$$anon$1.handleError(Jetty9Client.scala:468)
# 	at com.databricks.rpc.Jetty9Client$$anon$1.onFailure(Jetty9Client.scala:395)
# 	at shaded.v9_4.org.eclipse.jetty.client.ResponseNotifier.notifyFailure(ResponseNotifier.java:177)
# 	at shaded.v9_4.org.eclipse.jetty.client.ResponseNotifier.notifyFailure(ResponseNotifier.java:169)
# 	at shaded.v9_4.org.eclipse.jetty.client.HttpExchange.notifyFailureComplete(HttpExchange.java:268)
# 	at shaded.v9_4.org.eclipse.jetty.client.HttpExchange.abort(HttpExchange.java:240)
# 	at shaded.v9_4.org.eclipse.jetty.client.HttpConversation.abort(HttpConversation.java:149)
# 	at shaded.v9_4.org.eclipse.jetty.client.HttpRequest.abort(HttpRequest.java:768)
# 	at shaded.v9_4.org.eclipse.jetty.client.HttpDestination.abort(HttpDestination.java:453)
# 	at shaded.v9_4.org.eclipse.jetty.client.HttpDestination.failed(HttpDestination.java:234)
# 	at shaded.v9_4.org.eclipse.jetty.client.AbstractConnectionPool$1.failed(AbstractConnectionPool.java:140)
# 	at shaded.v9_4.org.eclipse.jetty.util.Promise$Wrapper.failed(Promise.java:136)
# 	at shaded.v9_4.org.eclipse.jetty.client.HttpClient$1$1.failed(HttpClient.java:612)
# 	at shaded.v9_4.org.eclipse.jetty.client.AbstractConnectorHttpClientTransport.connectFailed(AbstractConnectorHttpClientTransport.java:138)
# 	at shaded.v9_4.org.eclipse.jetty.client.AbstractConnectorHttpClientTransport$ClientSelectorManager.connectionFailed(AbstractConnectorHttpClientTransport.java:188)
# 	at shaded.v9_4.org.eclipse.jetty.io.ManagedSelector$Connect.failed(ManagedSelector.java:822)
# 	at shaded.v9_4.org.eclipse.jetty.io.ManagedSelector.processConnect(ManagedSelector.java:254)
# 	at shaded.v9_4.org.eclipse.jetty.io.ManagedSelector.access$1400(ManagedSelector.java:62)
# 	at shaded.v9_4.org.eclipse.jetty.io.ManagedSelector$SelectorProducer.processSelected(ManagedSelector.java:543)
# 	at shaded.v9_4.org.eclipse.jetty.io.ManagedSelector$SelectorProducer.produce(ManagedSelector.java:401)
# 	at shaded.v9_4.org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.produceTask(EatWhatYouKill.java:360)
# 	at shaded.v9_4.org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.doProduce(EatWhatYouKill.java:184)
# 	at shaded.v9_4.org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.tryProduce(EatWhatYouKill.java:171)
# 	at shaded.v9_4.org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.run(EatWhatYouKill.java:129)
# 	at shaded.v9_4.org.eclipse.jetty.util.thread.ReservedThreadExecutor$ReservedThread.run(ReservedThreadExecutor.java:367)
# 	at shaded.v9_4.org.eclipse.jetty.util.thread.QueuedThreadPool.runJob(QueuedThreadPool.java:782)
# 	at shaded.v9_4.org.eclipse.jetty.util.thread.QueuedThreadPool$Runner.run(QueuedThreadPool.java:914)
# 	at java.lang.Thread.run(Thread.java:748)
# Caused by: java.net.ConnectException: Connection refused
# 	at sun.nio.ch.SocketChannelImpl.checkConnect(Native Method)
# 	at sun.nio.ch.SocketChannelImpl.finishConnect(SocketChannelImpl.java:714)
# 	at shaded.v9_4.org.eclipse.jetty.io.SelectorManager.doFinishConnect(SelectorManager.java:355)
# 	at shaded.v9_4.org.eclipse.jetty.io.ManagedSelector.processConnect(ManagedSelector.java:232)
# 	... 11 more

# %%
best_model=model.bestModel

predictions=best_model.transform(test)

predicted_ratings_df = predictions.filter(predictions.prediction != float('nan'))

rmse=evaluator.evaluate(predicted_ratings_df)

print("RMSE = " + str(rmse))
print("**Best Model**")
print(" Rank:"),best_model.rank
print(" MaxIter:"),best_model._java_obj.parent().getMaxIter()
print(" RegParam:"),best_model._java_obj.parent().getRegParam()

# %% [markdown]
# The best model has 22 latent factors and regulization = 0.1
# The RMSE is 1.89644273379, which is bigger than both IBCF= 1.1570069 and UBCF= 0.9240670 from the previous project

# %%
display(predicted_ratings_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>itemId</th><th>rating</th><th>userIndex</th><th>itemIndex</th><th>prediction</th></tr></thead><tbody><tr><td>A3UZV6KHEPQKQ5</td><td>B00CDBQNZU</td><td>5.0</td><td>17753.0</td><td>31.0</td><td>2.8665416</td></tr><tr><td>A2UWXEEWIKFPBP</td><td>B00CDBQNZU</td><td>5.0</td><td>897.0</td><td>31.0</td><td>3.7309794</td></tr><tr><td>A2Y2JTGER56QR4</td><td>B00CDBQNZU</td><td>5.0</td><td>4119.0</td><td>31.0</td><td>1.6496632</td></tr><tr><td>A2L3FAPDVEUL5K</td><td>B00CDBQNZU</td><td>1.0</td><td>16234.0</td><td>31.0</td><td>2.8665416</td></tr><tr><td>A07210292XA7ZPKESLMC8</td><td>B00CDBQNZU</td><td>4.0</td><td>5375.0</td><td>31.0</td><td>2.9191685</td></tr><tr><td>A2T4OL4DO5CF6V</td><td>B00CDBQNZU</td><td>5.0</td><td>15093.0</td><td>31.0</td><td>3.5831769</td></tr><tr><td>A3S48Q63UPO9L6</td><td>B00CDBQNZU</td><td>5.0</td><td>13170.0</td><td>31.0</td><td>2.323049</td></tr><tr><td>AEQ5O09E7ERTB</td><td>B00CDBQNZU</td><td>4.0</td><td>18193.0</td><td>31.0</td><td>-0.09269881</td></tr><tr><td>A2NJOS6PYGAB5H</td><td>B00CDBQNZU</td><td>5.0</td><td>17196.0</td><td>31.0</td><td>2.199551</td></tr><tr><td>A1CFRFLS49G8R8</td><td>B00CDBQNZU</td><td>1.0</td><td>3313.0</td><td>31.0</td><td>3.799327</td></tr><tr><td>A22GWMIVVT70FD</td><td>B00CDBQNZU</td><td>5.0</td><td>9217.0</td><td>31.0</td><td>3.5831769</td></tr><tr><td>A1L7VHZBTOMQ9L</td><td>B00CDBQNZU
# %%
reg_eval = RegressionEvaluator(predictionCol="prediction", labelCol="rating", metricName="rmse")

# %% [markdown]
# #Recommendations
#
# Generate Recommendations for all users

# %%
user_rec=best_model.recommendForAllUsers(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(user_rec)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userIndex</th><th>recommendations</th></tr></thead><tbody><tr><td>148</td><td>List(List(15, 4.9310813), List(46, 4.7800746), List(6, 4.7537084), List(63, 4.7201915), List(1, 4.637907), List(60, 4.601981), List(10, 4.5879793), List(18, 4.5705414), List(39, 4.5512996), List(20, 4.523264))</td></tr><tr><td>463</td><td>List(List(24, 6.560636), List(62, 6.3836765), List(3, 6.249261), List(25, 6.135927), List(61, 5.940811), List(21, 5.9244184), List(53, 5.7974215), List(64, 5.7418127), List(57, 5.699632), List(33, 5.609172))</td></tr><tr><td>471</td><td>List(List(62, 6.1830344), List(32, 4.943763), List(7, 4.702999), List(14, 4.658553), List(61, 4.318445), List(12, 4.3122706), List(65, 3.9326615), List(1, 3.5566816), List(3, 3.4101014), List(37, 3.2326102))</td></tr><tr><td>496</td><td>List(List(12, 5.872194), List(32, 5.850674), List(51, 5.5642624), List(37, 5.533883), List(61, 5.507338), List(29, 5.4738364), List(9, 5.361377), List(18, 5.3560534), List(23, 5.082713), List(14, 5.0502806))</td></tr><tr><td>833</td><td>List(List(62, 6.6936264), List(3, 4.775024), List(31, 4.4702916), List(17, 4.4406714), List(36, 4.314538), List(61, 4.2573624), List(1, 4.2495894), List(65, 4.0683), List(30, 3.9462829), List(38, 3.9390357))</td></tr><tr><td>1088</td><td>List(List(54, 5.4669986), List(28, 5.211794), List(26, 5.1970687), List(4, 5.1481004), List(68, 5.0985236), List(35, 5.04649), List(27, 4.960038), List(16, 4.930458), List(5, 4.920898), List(56, 4.769057))</td></tr><tr><td>1238</td><td>List(List(67, 5.0436606), List(64, 5.037113), List(6, 5.035599), List(33, 4.958264), List(29, 4.907932), List(39, 4.8235645), List(55, 4.818003), List(35, 4.756812), List(28, 4.751462), List(15, 4.7511744))</td></tr><tr><td>1342</td><td>List(List(15, 4.9602337), List(10, 4.8338776), List(18, 4.826921), List(60, 4.802887), List(63, 4.757739), List(46, 4.611818), List(6, 4.576256), List(59, 4.5233107), List(58, 4.4695516), List(2, 4.463224))</td></tr><tr><td>1580</td><td>List(List(28, 5.0033064), List(67, 4.973325), List(0, 4.8970094), List(22, 4.8352075), List(11, 4.8274565), List(8, 4.772457), List(68, 4.7621307), List(55, 4.752386), List(35, 4.7518287), List(49, 4.701833))</td></tr><tr><td>1591</td><td>List(List(24, 5.280665), List(54, 5.0922127), List(56, 4.6291947), List(41, 4.614948), List(50, 4.5113573), List(44, 4.4997964), List(43, 4.4841704), List(0, 4.3178077), List(28, 4.2971864), List(27, 4.229585))</td></tr><tr><td>1829</td><td>List(List(11, 5.0886264), List(8, 5.0604353), List(22, 4.878569), List(49, 4.87597), List(39, 4.6585207), List(0, 4.627097), List(36, 4.621004), List(67, 4.605047), List(25, 4.6006746), List(4, 4.567636))</td></tr><tr><td>1959</td><td>List(List(67, 5.221072), List(35, 5.0725207), List(28, 5.065014), List(55, 5.056529), List(68, 5.0361943), List(6, 4.9707203), List(64, 4.942608), List(16, 4.9259253), List(33, 4.9018083), List(15, 4.8649936))</td></tr><tr><td>2122</td><td>List(List(62, 5.795812), List(7, 3.7597957), List(3, 3.4036875), List(17, 3.2168465), List(61, 3.1030226), List(21, 2.9358108), List(31, 2.9020176), List(32, 2.8644583), List(65, 2.7034936), List(12, 2.6686735))</td></tr><tr><td>2142</td><td>List(List(12, 4.777539), List(32, 4.5550385), List(37, 4.3183594), List(51, 4.277199), List(61, 4.247382), List(62, 4.2428308), List(24, 4.153714), List(29, 4.119118), List(9, 3.9980693), List(14, 3.9131806))</td></tr><tr><td>2366</td><td>List(List(10, 3.5789392), List(26, 3.4985526), List(68, 3.3045733), List(60, 3.262006), List(2, 3.2364914), List(35, 3.2288592), List(16, 3.2203438), List(59, 3.2184129), List(27, 3.2183084), List(15, 3.1537519))</td></tr><tr><td>2659</td><td>List(List(62, 5.9421396), List(17, 4.241562), List(31, 4.119923), List(30, 3.53367), List(3, 3.2544212), List(34, 3.121674), List(36, 2.9633756), List(7, 2.9419758), List(1, 2.5355077), List(38, 2.3884785))</td></tr><tr><td>28 ...

# %%
user_rec.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">85</span><span class="ansired">]: </span>136375</div>

# %% [markdown]
# Produce recommendations for one user

# %%
user = user_rec.filter(user_rec.userIndex==148)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(user)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userIndex</th><th>recommendations</th></tr></thead><tbody><tr><td>148</td><td>List(List(15, 4.9310813), List(46, 4.7800746), List(6, 4.7537084), List(63, 4.7201915), List(1, 4.637907), List(60, 4.601981), List(10, 4.5879793), List(18, 4.5705414), List(39, 4.5512996), List(20, 4.523264))</td></tr></tbody></table></div>

# %% [markdown]
# We can see that the algorithm is recommnding items with similar ratings, which is an indication that a user is getting similar items recommnded to them

# %%
rec=user.select("recommendations.itemIndex","recommendations.rating")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(rec)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>itemIndex</th><th>rating</th></tr></thead><tbody><tr><td>List(15, 46, 6, 63, 1, 60, 10, 18, 39, 20)</td><td>List(4.9310813, 4.7800746, 4.7537084, 4.7201915, 4.637907, 4.601981, 4.5879793, 4.5705414, 4.5512996, 4.523264)</td></tr></tbody></table></div>

# %%
import pandas as pd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rec_items=rec.select("itemIndex").toPandas().iloc[0,0]
rec_ratings=rec.select("rating").toPandas().iloc[0,0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rec_matrix=pd.DataFrame(rec_items,columns=["itemsIndex"])
rec_matrix["ratings"]=rec_ratings
ratings_matrix_df=sqlContext.createDataFrame(rec_matrix)
display(ratings_matrix_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>itemsIndex</th><th>ratings</th></tr></thead><tbody><tr><td>15</td><td>4.931081295013428</td></tr><tr><td>46</td><td>4.780074596405029</td></tr><tr><td>6</td><td>4.753708362579346</td></tr><tr><td>63</td><td>4.720191478729248</td></tr><tr><td>1</td><td>4.637907028198242</td></tr><tr><td>60</td><td>4.601981163024902</td></tr><tr><td>10</td><td>4.587979316711426</td></tr><tr><td>18</td><td>4.5705413818359375</td></tr><tr><td>39</td><td>4.551299571990967</td></tr><tr><td>20</td><td>4.523263931274414</td></tr></tbody></table></div>

# %% [markdown]
# We map the index of the items recommended back to their ids

# %%
test_items=test.dropDuplicates(['itemId','itemIndex']).select("itemId","itemIndex")
display(test_items)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
</td><td>26.0</td></tr><tr><td>B00DTOYIIE</td><td>4.0</td></tr><tr><td>B008QTTGGG</td><td>19.0</td></tr><tr><td>B005544TRQ</td><td>9.0</td></tr><tr><td>B009AP3HQK</td><td>42.0</td></tr><tr><td>B00CDBTVM2</td><td>24.0</td></tr><tr><td>B000OGTRC2</td><td>43.0</td></tr><tr><td>B00CBNOD0W</td><td>34.0</td></tr><tr><td>B00F0XPJH6</td><td>39.0</td></tr><tr><td>B003NRWVMC</td><td>60.0</td></tr><tr><td>B003NRVE6Q</td><td>63.0</td></tr><tr><td>B000OJFV3S</td><td>41.0</td></tr><tr><td>B00DAHSVYC</td><td>0.0</td></tr><tr><td>B00F87ZUYG</td><td>8.0</td></tr><tr><td>B008JSO21S</td><td>28.0</td></tr><tr><td>B00I3MNGCG</td><td>12.0</td></tr><tr><td>B000MVN8GK</td><td>51.0</td></tr><tr><td>B00APE00H4</td><td>10.0</td></tr><tr><td>B004KPX56C</td><td>50.0</td></tr></tbody></table></div>

# %%
user_recommendations=test_items.join(ratings_matrix_df,test_items.itemIndex==ratings_matrix_df.itemsIndex).drop("itemIndex","itemsIndex")
display(user_recommendations)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>itemId</th><th>ratings</th></tr></thead><tbody><tr><td>B004MWZLYC</td><td>4.5705413818359375</td></tr><tr><td>B00I3MPDP4</td><td>4.637907028198242</td></tr><tr><td>B00F0XPJH6</td><td>4.551299571990967</td></tr><tr><td>B003NRVE6Q</td><td>4.720191478729248</td></tr><tr><td>B003NRWVMC</td><td>4.601981163024902</td></tr><tr><td>B00H7NDSPC</td><td>4.780074596405029</td></tr><tr><td>B00APE00H4</td><td>4.587979316711426</td></tr><tr><td>B00B8P8O9K</td><td>4.753708362579346</td></tr><tr><td>B00C7KXUOE</td><td>4.523263931274414</td></tr><tr><td>B006Z48TZS</td><td>4.931081295013428</td></tr></tbody></table></div>

# %% [markdown]
# This table shows the recommended items for the selected user and the corresponding ratings.

# %% [markdown]
# ##Conclusion
#
# The goal of this project was to practice working with a distributed recommnder system.
# We were able to adapt an ALS recommender system to work with Apache Spark via Databricks platform. The dataset that was used to build the model was the same as in Project 4 where IBCF anf UBCF collaborative systems were build in order to recommend new items to users. The best performing algorithm was UBCF with RMSE of 0.9240670.
# The advantages of working with Spark as oppose to local memory were its ability to handle the entire dataset of 583933 where before was almost impossible and the high-level libraries, including support for SQL queries.
#
# The architechture of Apache Spark-- "At a fundamental level, an Apache Spark application consists of two main components: a driver, which converts the user's code into multiple tasks that can be distributed across worker nodes, and executors, which run on those nodes and execute the tasks assigned to them. Some form of cluster manager is necessary to mediate between the two." from https://www.infoworld.com/article/3236869/what-is-apache-spark-the-big-data-platform-that-crushed-hadoop.html
#
# The ALS model that we build resulted in 22 latent factors and regulization = 0.1 with RMSE of 1.89644273379, which is bigger than both IBCF= 1.1570069 and UBCF= 0.9240670 from the previous project. Although when evaluating the model we can see that the items that were recommended to one user were all with similar ratings.
# A possible improvemnet of the model might include some implicit data where we can also have additional information such as genre, number of views, clicks, purchases etc and set the implicitPrefs=True to get a better idea of the similarity of the iteams and also to improve the results/improve the model.
